# %%
import pandas as pd, json, os, re, zipfile, pathlib
excel_path = r"C:\Users\sanaz\OneDrive\Documents\ThePriceofLibertyMAP\ListOfNames.xlsx"
site_dir   = r"C:\Users\sanaz\OneDrive\Documents\ThePriceofLibertyMAP"
os.makedirs(site_dir, exist_ok=True)

googlesheet = 'https://docs.google.com/spreadsheets/d/19IE4FLYkJ1MAvawhhZx5WEnj0xowtOIoqPIB-E-6rSU/edit?usp=sharing'
sheet_id = "19IE4FLYkJ1MAvawhhZx5WEnj0xowtOIoqPIB-E-6rSU"
gid = 0  # change if desired tab isn't the first one
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid}"
df = pd.read_csv(url)
df['Name in Farsi'] = df['Name in Farsi'].str.strip()
df['Name in English'] = df['Name in English'].str.strip()

# %%
import pandas as pd
from rapidfuzz import fuzz
COLUMN = "Name in Farsi"
FUZZY_THRESHOLD = 92  # very high similarity
def normalize(text):
    if pd.isna(text):
        return ""
    return str(text).strip().lower()
def find_similar_names(df):
    names = df[COLUMN].apply(normalize).tolist()
    results = []

    n = len(names)

    for i in range(n):
        for j in range(i + 1, n):  # avoid self + duplicate comparisons
            name1 = names[i]
            name2 = names[j]

            if not name1 or not name2:
                continue

            # Exact match
            exact = name1 == name2

            # Fuzzy match
            similarity = fuzz.ratio(name1, name2)
            fuzzy = similarity >= FUZZY_THRESHOLD

            if exact or fuzzy:
                results.append({
                    "index_1": i,
                    "index_2": j,
                    "name_1": df.iloc[i][COLUMN],
                    "name_2": df.iloc[j][COLUMN],
                    "similarity": similarity,
                    "row_1": df.iloc[i],
                    "row_2": df.iloc[j],
                })

    return results
def print_results(matches):
    for k, match in enumerate(matches, 1):
        print(f"\n========== MATCH {k} ==========")
        print(f"Similarity: {match['similarity']}")
        print(f"""{match["name_1"]} == {match["name_2"]}\n""")
matches = find_similar_names(df)

# %%
listofnames = []
for k, match in enumerate(matches, 1):
    if match['similarity'] == 100:
        listofnames.append(match["name_1"])

print(len(set(listofnames)))

set(listofnames)

# %% [markdown]
# #### Scrape from IG

# %%
dr = r"C:/Users/sanaz/Downloads/subset_parq/"
import pandas as pd
import glob

# path where your parquet files are
path = dr + "*.parquet"

files = sorted(glob.glob(path))

dfs = []
for f in files:
    df = pd.read_parquet(f)
    dfs.append(df)

final_df = pd.concat(dfs, ignore_index=True)

# ---- SHAPE
print("Shape:", final_df.shape)
# Out:
# Shape: (43950, 67)

# %%
final_df.to_csv(dr+"final_df.csv", index=False)

# %%
final_df['month_year'] = final_df['L2_casecreateddatetime'].apply(lambda x: "-".join(str(x).split("-")[0:2]) )

# %%
monthly = (
    final_df
    .groupby("month_year")["L2_caseid"]
    .nunique()
    .reset_index(name="cases")
    .sort_values("month_year")
)

monthly
# Out:
#    month_year  cases
# 0     2024-11   2316
# 1     2024-12   2281
# 2     2025-01   2694
# 3     2025-02   2402
# 4     2025-03   2505
# 5     2025-04   2336
# 6     2025-05   2573
# 7     2025-06   2447
# 8     2025-07   2519
# 9     2025-08   2407
# 10    2025-09   2370
# 11    2025-10   2672
# 12    2025-11   2547
# 13    2025-12   2591
# 14    2026-01   2795
# 15    2026-02   2799
# 16    2026-03   3425
# 17    2026-04    271

# %%
baseline = final_df[final_df["month_year"] == "2025-11"]
spike = final_df[final_df["month_year"].isin(["2026-01", "2026-02"])]

baseline_counts = baseline.groupby("complaint_theme")["L2_caseid"].nunique()
spike_counts = spike.groupby("complaint_theme")["L2_caseid"].nunique()

delta = (spike_counts - baseline_counts).sort_values(ascending=False)
delta.head(10)
# Out:
# complaint_theme
# Fees & Charges            201.0
# Account Servicing         140.0
# Fraud & Scams             121.0
# Promotions & Offers        78.0
# Digital Banking            64.0
# Transaction Processing     51.0
# Service Quality            47.0
# Collections                41.0
# Fraud                      40.0
# Disputes                   38.0
# Name: L2_caseid, dtype: float64

# %%
escalated = final_df[final_df["L1_caseid"].notna()]
escalated["escalation_reason"].value_counts().head(10)
# Out:
# escalation_reason
# Direct to L2                          8242
# Unresolved at L1                      2131
# Inadequate L1 Resolution              1455
# Failure to Resolve                    1443
# Unsatisfactory L1 Resolution          1269
# Dissatisfaction with Outcome          1194
# direct to l2                          1031
# Dissatisfaction with L1 Outcome        868
# Dissatisfaction with L1 Resolution     823
# Dissatisfaction with Resolution        818
# Name: count, dtype: int64

# %%
for i in escalated["escalation_reason"].unique():
    print(i)
# Out:
# Resolution Delay
# Inadequate L1 Resolution
# Unresolved at L1
# Failure to Resolve
# Dissatisfaction with Resolution
# Lack of L1 Empowerment/Knowledge
# Process Delay
# direct to l2
# Lack of Response
# Policy Constraint
# Failure to Resolve at L1
# Failure to Follow-up
# Unresolved Issue
# Disagreement with Initial Outcome
# Dissatisfaction with L1 Response
# Dissatisfaction with L1 Finding
# Dissatisfaction with Policy
# Policy/Process Issue
# L1 Unable to Resolve
# Dissatisfaction with L1 Resolution
# L1 Service Failure
# L1 Failure to Resolve
# Failure to Resolve at Frontline
# Unsatisfactory L1 Resolution
# Incorrect Information Provided
# Unsatisfactory L1 Response
# Unsatisfactory Resolution
# Follow-up on Prior Case
# Dissatisfaction with Explanation
# Investigation Delay
# Dissatisfaction with L1 Decision
# L1 Resolution Failure
# Inability to address strategic query
# Inadequate L1 Investigation
# Insufficient Explanation at L1
# Dissatisfaction with Outcome
# Poor Complaint Handling
# L1 Lacked Authority/Knowledge
# Perceived Poor Service
# Prior Unsuccessful Contact
# L1 Resolution Ineffective
# Unsatisfactory Timeline
# Dissatisfaction with L1 Outcome
# Investigation Required
# Inadequate L1 Empowerment/Process
# Delayed Resolution
# Resolution Not Provided
# Poor Service Experience
# Inability to Resolve at L1
# Unsatisfactory Branch Response
# Inadequate Explanation
# Unable to Provide Information
# Lack of L1 Resolution
# Incomplete Investigation
# Lack of L1 Empowerment/Tools
# Poor L1 Handling
# Unresolved at First Point of Contact
# Service Dissatisfaction
# L1 Authority Limits
# Unsatisfactory Explanation
# L1 Lacked Technical Expertise
# Unresolved Inquiry
# Dissatisfaction with Solution
# System Error
# Dissatisfaction with L1 Explanation
# L1 Knowledge Gap
# Inadequate Resolution Offer
# Unsatisfactory L1 Outcome
# Denied Request
# L1 Decision
# Unkept Promise
# L1 Inability to Resolve
# Failed Resolution
# Dissatisfaction with Process
# Dissatisfied with Explanation
# Inadequate Resolution/Explanation
# L1 Failed to Explain
# Policy Dissatisfaction & Service Error
# First Contact Resolution Failure
# Unsatisfactory L1 Explanation
# Customer Request
# Customer Request for Escalation
# Inadequate Branch Offer
# Inadequate Resolution
# Policy Exception Required
# Unresolved at First Contact
# Dissatisfaction with Policy Explanation
# Lack of Follow-up
# Unsatisfactory Response
# Inability to Resolve
# Unsatisfactory Frontline Response
# Lack of L1 Authority
# Loss of Confidence
# Dissatisfaction with Decision
# L1 Empowerment/Policy
# Resolution Ineffective
# Agent's Incorrect Advice
# Unresolved Rate Dispute
# Lack of Timely Resolution
# Disagreement with Policy
# Process Driven Escalation
# Failure to Resolve at First Contact
# Unknown
# Compensation Request
# L1 Incapacity to Resolve
# Unresolved L1 Issue
# No Response
# Unresolved Prior Complaint
# Resolution Not Implemented
# Unsatisfactory L1 Interaction
# No L1 Resolution
# Dissatisfaction with L1 Handling
# Requires Back-Office Investigation
# Dissatisfaction with Previous Outcome
# Failed L1 Resolution
# Failure to Investigate/Resolve
# Complaint Complexity
# Resolution Required Higher Authority
# L1 Resolution Dissatisfaction
# Incomplete L1 Resolution
# Agent System Limitation
# Perceived Delay
# Failure to Fulfill Request
# Resolution Dissatisfaction
# Dissatisfaction with Initial Outcome
# Dissatisfied with L1 Advice
# Incorrect Advice Provided
# L1 Unresolved
# Dispute Adjudication
# Frontline Inability to Resolve
# L1 Inaction
# Customer Dissatisfaction with Explanation
# Lack of Resolution / Follow-up
# Staff Conduct
# Allegation of Misconduct
# Loss of Confidence in Staff
# L1 Offer Rejected
# Incomplete Resolution
# Incomplete L1 Handling
# No L1 Resolution Attempt
# Lack of Update
# L1 Incapable of Resolution
# Unsatisfactory Solution Offered
# Unfulfilled Promises
# Dissatisfaction with Service
# L1 Unable to Meet Request
# Unresolved at Frontline
# Requires Technical Investigation
# Process Failure at L1
# Customer Request to Escalate
# Unsatisfactory Outcome
# Dissatisfaction with Staff
# Unresolved Grievance
# Exceeded L1 Mandate
# Process Failure
# Unresolved Delay
# Process Requirement
# Fee Dispute
# Customer Dissatisfaction
# Dissatisfaction with L1 Interaction
# Lack of Resolution
# Unresolved Issue & Delay
# Process/Policy Limitation
# L1 Resolution Rejected
# Unmet Customer Expectation
# Resolution Failure
# Dissatisfaction with Branch Decision
# L1 Lacked Authority
# Unaddressed Service Complaint
# Unresolved L1 Inquiry
# Agent Incapable/Unauthorized
# Financial Loss
# Resolution Inadequate
# Lack of L1 Empowerment/Process
# Inconsistent/Incorrect Information
# Disagreement with Decision
# Customer Disagrees with L1 Finding
# Incorrect Information
# Dissatisfaction with Branch Process
# Dissatisfaction with Branch Response
# Insufficient L1 Resolution
# Initial Request Denied
# Lack of Action
# Manager Unavailable
# Procedural Escalation
# L1 Lacked Empowerment
# Rejected Resolution / Compensation Dispute
# Poor Agent Conduct
# Resolution Authority
# Unsatisfactory Resolution Timeframe
# L1 Mandate/Scope
# Customer Dissatisfaction & Request
# Process Complexity
# Disagrees with Outcome
# Request Not Met
# Agent Authority/Process
# Unsatisfactory Rate & Rationale
# Failed Local Resolution
# Failure to Address Complaint
# Premature Case Closure
# Unresponsive Frontline
# L1 Lacked Authority/Capability
# Severity of Allegations
# Failure to Diagnose
# Recurring Issue
# L1 Resolution Not Accepted
# Lack of Explanation
# Unresolvable Request at L1
# Failure to Resolve by Frontline
# Investigation Delay & Error
# Jurisdiction/Scope Issue
# Frontline Inaction
# Request for Exception
# Dissatisfaction with Timeline
# Resolution Did Not Address Core Issue
# Ineffective L1 Resolution
# L1 Process Limitation
# Dissatisfaction with Branch Service
# None
# Conflicting Information
# Loss of Trust
# Nature of Complaint
# Failure to Resolve at Branch
# Unsuitable Resolution Path
# Request for Investigation
# Unacceptable Resolution
# Disagreement on Resolution
# Lack of Empowerment/Capability
# Compensation Exceeds Authority
# Investigation Requested
# no linked l1
# Inadequate L1 Explanation
# Incorrect Advice
# Dissatisfaction with Staff Conduct
# Policy Limitation at L1
# Dissatisfied with L1 Outcome
# Dissatisfaction with Claims Decision
# Frontline Staff Advice
# Unsatisfactory Resolution Offered
# Delay / No Action Taken
# Poor Service & Unfulfilled Promise
# Policy Disagreement
# Disagreement with Bank's Position
# L1 Non-Resolution
# Failure to Fulfill Promise
# Dissatisfaction with Agent
# Refusal to Assist
# Inconsistent Information
# Resolution SLA Breach
# Unsatisfactory Answer
# Factual Disagreement
# Inadequate Response
# No Follow-up
# Unmet Compensation Demand
# Staff Unavailability
# Jurisdictional Issue
# Denied Claim
# Inadequate Investigation
# Lacked Authority
# Client Requested Escalation
# Resolution Rejected
# Frontline Service Failure
# Dissatisfied with Outcome
# Process Hand-off
# Delay in Resolution
# SLA Management Failure
# L1 Triage
# Dissatisfaction with Prior Response
# Unresolved Credit Impact Concern
# Resolution Delay / No Follow-up
# Failed Resolution Promise
# Unresolved at Lower Level
# Unsatisfactory Resolution Offer
# Failure to Action Request
# Poor L1 Service Experience
# L1 Lacks Resolution Authority
# Lack of L1 Investigation
# Inability to Fulfill Request
# Complaint Handling Failure
# L1 Incapable/No Authority
# Previous Unresolved Issue
# Resolution Offer Rejected
# Service Failure
# L1 Agent Inability to Resolve
# L1 Failed to Investigate
# Unprofessional Conduct
# Refusal to Escalate
# Policy/Procedure Dispute
# L1 Lacks Authority
# Lack of L1 Empowerment/Capability
# Policy/Procedure Disagreement
# Unmet Expectation
# Process Limitation
# Customer Escalation Request
# Policy Dissatisfaction
# Resolution Handling
# Dissatisfied with L1 Resolution
# Unresolved at Touchpoint
# Dissatisfaction with Prior Decision
# Client Dissatisfaction
# Unnecessary Escalation
# Dissatisfaction with L1 Process
# Agent-Client Interaction Breakdown
# Request for Manager
# Dissatisfaction with Proposed Resolution
# Failure to Contain Fraud
# Unsatisfactory Resolution & Staff Conduct
# Policy Rejection
# Poor Staff Conduct
# L1 Empowerment/Authority
# Unable to Resolve
# Dissatisfaction with Branch Resolution
# Dissatisfaction with Proposed Solution
# Dissatisfaction with Policy Application
# Lack of Information
# Dissatisfied with Resolution
# Financial Impact & Compensation Request
# Inadequate L1 Process/Tools
# Lack of Ownership
# Client Request
# Process Inadequacy
# Poor Customer Service
# Agent Authority/Capability
# Previous Unresolved Complaint
# Initial Service Failure
# Unresolved Issue at L1
# Waiver Request Exceeds Authority
# Incorrect Process Followed
# Policy Constraint at L1
# Factual Dispute
# Unsatisfactory Investigation Outcome
# Customer Dissatisfaction with Process
# Unsatisfactory Branch Resolution
# Frontline Authority Limits
# Severity of Allegation
# Client Behavior
# Process Inflexibility
# Failure to Accommodate
# Resolution Timeline
# Unsatisfactory Initial Interaction
# Unsatisfactory Frontline Resolution
# Inflexible Policy
# Resolution Not Offered/Possible
# L1 Resolution Unacceptable
# Dissatisfaction with Frontline
# Inadequate Resolution/Offer
# Customer Dissatisfaction with Policy
# L1 Lacks Authority/Knowledge
# Dissatisfied with L1 Explanation
# Failure to Meet Commitment
# Unacceptable Resolution Timeline
# Unresolved Core Issue
# Unfulfilled Promise
# Inadequate L1 Tools/Authority
# Inadequate Compensation
# Channel Misdirection
# Severity of Incident
# Unresolved Issue & Poor Service
# Inability to meet customer request
# Unsatisfactory Previous Resolution
# No Resolution at L1
# Agent Error
# Process Dissatisfaction
# Prior Resolution Failure
# Failure to Resolve at First Point of Contact
# L1 Failed to Resolve
# Customer Runaround
# Policy Limitation
# Inadequate L1 Response
# Resolution Communication Failure
# L1 Scope Limitation
# Inadequate Compensation Offered
# Poor Agent/Manager Conduct
# Lack of L1 Empowerment
# Unaddressed Grievance
# Process Limitation at L1
# Incorrect L1 Resolution
# Claim Processing Time
# Customer Disagreement
# Unacceptable Resolution Timeframe
# Claim Decision Disagreement
# Resolution Not Delivered
# Lack of Resolution/Follow-up
# Dissatisfaction with Frontline Service
# Unresolved Underlying Issues
# Unacceptable Resolution Offered
# Resolution Not Accepted
# L1 Lacked Mandate
# Severity of Issue
# Agent Authority Limits
# Dissatisfaction with Bank Decision
# L1 Lacked Empowerment/Tools
# Lack of First Contact Resolution
# Specialized Investigation Required
# Scope/Capability Limitation
# Unaddressed Service Concerns
# Unsatisfactory Staff Conduct
# Request to Speak with Manager
# Process Breakdown
# Resolution Not Fulfilled
# Branch Non-Response
# Inadequate Frontline Support
# Conflicting Advice
# Financial Loss Claim
# Client Request for Escalation
# Compensation Demand
# Unresolved Query
# Inadequate L1 Solution
# Unsuccessful Funds Recovery
# Dissatisfaction with Business Decision
# Unresolved Compensation Request
# Dissatisfaction with Branch Experience
# Severity of Agent Misconduct
# Agent Inability to Fulfill Request
# Customer Demands
# Frontline Resolution Failure
# Claim Decision Dissatisfaction
# L1 Incapability
# Unmet Customer Demand
# Failure to Resolve / Follow-up
# Unsatisfactory L1 Handling
# Direct to L2 via Regulator
# No Response from Branch
# Hand-off for Investigation
# Requires Specialist Team
# Service Failure Impact
# Repeat Issue
# Complex Investigation
# Resolution Not Met
# Financial Loss Incurred
# Failed Escalation Handling
# Prior Complaint Mishandling
# Capability Gap at L1
# Insufficient Resolution
# Lack of In-Branch Resolution
# Inaccessible Service
# Dissatisfaction with Prior Resolution
# Dissatisfaction with Information Provided
# Unresolved Financial Dispute
# No L1 Resolution Attempted
# Unresolved L1 Concern
# L1 Agent Lacked Authority
# Unresolved L1 Complaint
# Unresolved L1 Request
# Dissatisfaction with L0 Resolution
# L1 Process Failure
# Agent Inability to Resolve
# Lack of L1 Capability
# Non-Resolution at L1
# Conflicting Information from Staff
# L1 Unable to Investigate/Resolve
# Dissatisfaction with Answer
# Supervisor Request
# Failed Resolution & Compensation Request
# Refusal to Waive Fee
# Dissatisfaction with L1 Timeline
# Policy Exception Denied
# Dissatisfaction with Explanation/Outcome
# Inadequate Resolution Offered
# Prior Unresolved Issue
# Agent Empowerment/Tool Limitation
# Lack of Communication
# Policy Review Request
# Misinterpreted Request
# Declined Exception Request
# Dissatisfied with Policy
# Initial Agent Error
# Dissatisfied with Claim Outcome
# Unsatisfactory Resolution Time
# Lack of L1 Follow-up
# No Available Solution
# Unaddressed Core Issue
# Complaint Handling
# Failure to Resolve at Source
# Seriousness of Allegation
# Unsatisfactory Resolution at L1
# Compensation Dispute
# Customer Disagrees with Outcome
# Policy/Process Limitation
# Complexity of Issue
# Customer Behavior
# Rate Dissatisfaction
# Unresolved Complaint
# Policy Misalignment
# Dissatisfaction with Staff Response
# Systemic Process Issue
# No Resolution Offered
# Failure to Explain
# Persisting Dissatisfaction
# Inflexible Policy/Process
# Lack of Internal Response
# Failure to provide basic service
# Unresolved Systemic Issue
# Disagreement with Outcome
# Previous Resolution Failure
# Scope/Authority
# Refusal to Investigate
# Direct Escalation by L1
# Lack of Information at L1
# Prolonged Resolution Time
# Unresolved Rate Dissatisfaction
# Procedural Requirement
# Request for Supervisor
# Financial Impact
# Specialized Team Needed
# Lacks Authority
# Unsatisfied with Resolution
# Unresolved Fraud Claim
# L1 Mandate/Authority
# Complaint Complexity/Severity
# Decision Disputed
# L1 Agent Inability
# Client Dissatisfaction with Process
# Direct to L2
# Dissatisfaction with Offered Rate
# L1 Resolution Inadequate
# Complaint About Complaint Process
# Unsatisfactory Branch Service
# Unsatisfactory Decision
# Agent Knowledge/Tool Gap
# Dissatisfaction with L1 Agent
# Dissatisfaction with Offer
# Policy Challenge
# Agent Knowledge Gap
# Dissatisfaction with Explanation/Solution
# No Linked L1
# Lack of Progress
# L1 Lacked Authority/Expertise
# Unsatisfactory Information
# Dissatisfaction with L1 Investigation
# Denial of Request
# L1 Unresponsiveness
# Initial Decision
# Resolution Not Offered
# Unsatisfactory Service
# Unresolved Financial Loss
# Unsatisfactory Initial Response
# Client Dissatisfaction with L1 Explanation
# Customer Requested Escalation
# L1 Resolution Failed
# Unresolved Request
# Inadequate Explanation/Investigation
# Unsatisfactory Resolution Option
# Unresolved Dissatisfaction
# L1 Dissatisfaction
# Complex Historical Dispute
# Agent Unable to Resolve
# In-branch Escalation Failure
# Dissatisfaction with Initial Decision
# Dissatisfaction with Resolution/Timeline
# Inadequate Branch Resolution
# Inadequate Communication
# Request Exceeds L1 Authority
# Resolution Failure at L1
# Dissatisfaction with Policy/Decision
# Unresolved Inquiry at L1
# Dissatisfied with Explanation/Policy
# Departmental Handoff Failure
# Issue Beyond L1 Scope
# Unresponsive Advisor
# Agent Incapable/Process Gap
# Impact of Bank Error
# Service Refusal at Frontline
# Agent Access/Authority Limitation
# Failure to resolve at initial touchpoint
# Failed Resolution at First Contact
# Inadequate Solution
# Unsatisfactory Explanation/Resolution
# Incorrect L1 Diagnosis
# Dissatisfaction with Agent Conduct
# Inadequate L1 Triage/Handling
# Compensation Dissatisfaction
# Inadequate Information
# Poor L1 Service
# Advisor Unresponsive
# Unsatisfactory L1 Process
# Disagreement with L1 Finding
# L1 Unable to Fulfill Request
# Inadequate L1 Authority
# Internal Non-Response
# Incorrect Information from L1
# Inadequate L1 Offer
# Poor L1 Experience
# Customer Request for Assurance
# Request for Call Review
# Dissatisfaction with L1 Service
# Unresolved Service Issue
# Lack of Authority/Involvement
# Incorrect Advice at L1
# L1 Authority Limit
# Unsatisfactory Resolution / Offer
# Unresolved Service Dissatisfaction
# Policy/Decision Challenge
# Unclear Resolution/Next Steps
# Inadequate Explanation/Resolution
# Inability to Resolve Technical Issue
# Unresolved Fee Dispute
# Dissatisfaction with L1 Advice
# Proactive Escalation by Staff
# Service Failure at L1
# Unaddressed Issue at L1
# Inadequate Compensation Offer
# Inadequate Branch Response
# Prior Service Failure
# Lack of L1 Empowerment/Info
# Lack of Empowerment/Access
# Unresolved at Branch
# Unresponsiveness
# Dissatisfaction with Prior Service
# L1 Triage/Transfer
# Auto-Escalation
# L1 Process/Authority Gap
# Unsatisfactory Resolution Timeline
# L1 Decision Disputed
# Lack of Empowerment
# Issue Persistence
# Inability to Resolve at First Contact
# Process Frustration
# Inconsistent L1 Information
# Agent Attitude & Decision
# Resolution Rejected by Customer
# Poor Communication
# Empowerment/Policy Limitation
# Failure to Resolve / Inadequate Solution
# Dissatisfaction with L1 Explanation/Resolution
# L1 Inaction / Delay
# L1 Agent Misunderstanding
# Disagreement with Bank Decision
# L1 Referral
# Unsatisfied with Explanation
# L1 Timeliness Failure
# Dissatisfaction with Resolution Timeframe
# Unsatisfactory L1 Finding
# Rejected L1 Resolution
# Dissatisfaction with Information
# Lack of Empowerment/Knowledge
# Inadequate Investigation/Information
# Communication Breakdown
# L1 Misunderstood Complaint
# Unclear Complaint/Agent Inability to Clarify
# Dissatisfaction with Previous Resolution
# Issue Complexity
# L1 Incapable of Resolving
# L1 Non-Contact
# Dissatisfaction with Policy/Explanation
# Lack of L1 Authority/Information
# Customer-Agent Disagreement
# Agent Incapable of Resolving
# Automated Escalation
# Exception Request Declined
# Lack of Empowerment/Authority
# Disagreed with Claim Decision
# Impact on Credit Score
# Unsatisfactory Solution
# Denied Financial Restitution
# L1 Agent Unable to Resolve
# Unclear Root Cause at L1
# Perceived Inflexibility
# Unresolved Frustration
# Agent Empowerment
# Dissatisfaction with Response
# Policy/Procedure Followed
# Failure to Resolve at Lower Level
# Poor Agent Experience
# L1 Resolution Unsatisfactory
# L1 Unable to Change Offer
# Resolution Not Actioned
# Dissatisfaction with L1/Previous Outcome
# Lapse in Resolution Time
# Dissatisfaction with Prior Outcome
# Dissatisfaction with Policy/Solution
# Client Unavailability
# Inability to Investigate
# Dissatisfaction with Dispute Outcome
# Poor L1 Handling / Runaround
# Dissatisfaction with Claim Decision
# Inadequate Explanation at L1
# L1 Process Gap
# L1 Inaction / No Resolution
# Unresponsive Branch
# Failed Promise
# No L1 Resolution Offered
# Perceived Unfair Treatment
# Lack of Resolution/Answer
# Lacked Authority/Tools
# Unresponsive Staff
# Dissatisfaction with Initial Response
# Staff Inability to Resolve
# Poor Service at Touchpoint
# Customer Insistence
# Inability to Reach Agent
# Dissatisfaction with L1 Solution
# Improper Escalation
# Supervisor Refusal
# Staff Misconduct
# Third-Party Misconduct
# Demand Not Met
# Dissatisfaction with Offered Resolution
# Unclear/Inadequate Explanation
# Lack of Investigation
# Service Refusal
# L1 Mandate/Process Limitation
# Dissatisfaction with Staff Attitude
# Agent Lacked Knowledge
# L1 Lacks Authority/Information
# Request Complexity
# Initial Request Declined
# Perceived Privacy Breach
# Incorrect L1 Decision
# System Auto-Escalation
# Appeal of Bank Decision
# Denied Escalation
# Frontline Failure to Assist
# SLA Breach
# Inaccessible Support Channel
# Agent Lacked Information
# Disagreement with Agent
# Process Delays & Repeated Requests
# Customer Dissatisfaction with Resolution
# Demand for Manager
# Excessive Wait Time
# L1 Process/Authority Limit
# L1 Failure to Investigate
# Claim Denial
# Failure to Follow Up
# Failure of Frontline Support
# Required Specialist
# System/Process Error
# Dissatisfaction with Bank's Stance
# Unanswered Inquiry
# Information Not Available at L1
# L1 Lacked Authority/Info
# L1 Unable to Investigate
# Customer Unhappy with L1 Explanation
# Unresponsive at First Point of Contact
# Partner Resolution Failure
# Client Rejected Solution
# Lapse of Time
# Compounded Service Failure
# Complexity/Authority
# Complexity of Request
# Complexity of Issues
# Agent Error / Lack of Knowledge
# Information Gap at L1
# Customer Disagrees with Policy
# Unsatisfactory Business Line Response
# L1 Empowerment Issue
# Unsatisfactory Resolution/Advice
# Legal Threat
# Unclear Information at L1
# Previous Interaction Failure
# Appeal of Prior Decision
# Inability to Connect
# Ineffective Branch Process
# Lack of Resolution at Branch
# Exceeded SLA
# L1 Handling Failure
# Process/Policy Limitation at L1
# Resolution Not Honored
# Dissatisfaction with Bank's Action
# Inability to Authenticate Customer
# Unclear Process/Next Steps
# L1 Lacked Information
# Credit Decision Dispute
# L1 Agent Authority/Capability
# Related to Existing Escalation
# Client Demanded Escalation
# Unclear Resolution Path
# Unsatisfactory Specialist Department Response
# Frontline Failure to Resolve
# Unresolved Process Confusion
# Resolution Not Possible at L1
# Disagreed with Process
# L1 Process Knowledge Gap
# Policy/Decision Dispute
# Failure to Address Concerns
# Unclear Requirements
# Misinformation by Agent
# L1 Investigation Failure
# Service Runaround
# Failure to Understand Issue
# Delayed L1 Resolution
# Perception of Poor Service
# Unclear Communication
# Inadequate Financial Redress
# Unresolved Underlying Issue
# Partial Resolution
# Severity of Complaint
# Failure to Communicate
# Perceived Unfair Process
# Complaint Severity
# Improper Escalation Handling
# Supervisor Request Not Met
# Poor Customer Experience
# Failed Branch Resolution
# Poor Communication / Slow Progress
# Unsatisfactory Prior Response
# Inability to Resolve at First Point of Contact
# Technical Issue Unresolved at L1
# Financial Reimbursement Request
# L1 Lacked Authority/Process
# L1 Unable to Resolve/Explain
# Unsatisfactory Branch Experience
# Dissatisfaction with Investigation Outcome
# SLA Breach / Delay
# Incorrect L1 Assessment
# No Resolution Attempted at L1
# Unsatisfactory Agent Interaction
# Lack of L1 Empowerment/Investigation
# L1 Misinformation/Poor Advice
# L1 Process/Authority
# L1 Inadequate Resolution
# Lack of Resolution at L1
# Compensation Demanded
# Dissatisfaction with L1/Department Decision
# Resolution Mismatch
# Ineffective Explanation
# Dissatisfied with L1 Finding
# Previous Attempts Failed
# L1 Misunderstanding
# Dissatisfaction with Fraud Decision
# Lack of Progress/Update
# L1 Lacked Empowerment/Knowledge
# Failure to Action Instruction
# Demand Exceeds L1 Authority
# Initial Request Unresolved
# Agent Conduct / Attitude
# L1 Unable to Explain
# Failure to Restore Services
# Inadequate Resolution Communication
# Disagreed with Decision
# Internal Runaround
# Compensation Request Denied
# Inflexible Process
# Dissatisfaction with Resolution/Update
# Dissatisfaction with Agent Advice
# Resolution Timeframe Exceeded
# Perceived L1 Failure
# Unresolved Dispute
# Perceived Security Breach
# Dissatisfaction with L1 Findings
# Technical Limitation at L1
# Promise Not Kept
# Delayed/No Follow-up
# Non-Resolution at Touchpoint
# Poor Branch Experience
# L1 Agent Lacked Knowledge
# Dissatisfaction with L0 Interaction
# Customer Disagrees with Finding
# Unsatisfactory Process
# Dissatisfaction with Frontline Advice
# L1 Agent Authority/Mandate
# Dissatisfaction with Specialist
# Denial of Claim
# Insufficient Explanation
# Agent Error / Misinformation
# Complaint Type
# No Internal Response
# Desired Outcome Not Met
# Perceived Unfulfilled Promise
# Frontline Failure
# Unprofessional Staff Conduct
# No Update Provided
# Dissatisfaction with Prior Handling
# Poor In-Branch Complaint Handling
# Branch Unresponsiveness
# Decision Challenge
# Request Beyond L1 Scope
# Branch Unresponsive
# Request for Formal Investigation
# L1 Mandate Limitation
# Unacceptable Staff Behavior
# Dissatisfaction with Agent Response
# Failure to Address Core Issue
# Lack of Back-Office Response
# Disagreement with L1 Outcome
# L1 Deflection
# Policy/Authority Limit
# Failure to Investigate
# No Resolution/Response
# Consequential Loss
# Internal Support Failure
# Refusal to Share Evidence
# Appeal of L1 Decision
# Policy-based Rejection
# L1 Lacked Technical Fix Capability
# Direct Escalation Request
# Unsatisfactory Prior Resolution
# Partner Unresponsive
# Incorrect Escalation Path
# Failure to Accommodate Disability
# Desire to Report Systemic Issue
# Explanation Not Accepted
# Inability to Validate Offer
# L1 Triage to L2
# L1 Lacked Authority/Tools
# Client Challenging Bank Policy
# Agent Lacked Authority
# Dissatisfied with L1 Response
# Reimbursement Delay
# Customer Dissatisfaction with L1 Resolution
# Resolution Not Communicated
# Unsatisfactory L1 Answer
# Failure to Resolve & New Issues
# Unresolved Request for Compensation
# Unacceptable Delay
# L1 Service Delay
# Requires Specialist Investigation
# Lack of Timely Update
# Resolution Fulfillment
# Unresolved Service Grievance
# L1 Agent Knowledge Gap
# Inadequate L1 Support
# Calculation Complexity
# Agent Decision
# No Solution Available
# Failed Resolution Attempt
# Lack of Follow-up / Resolution
# Previous Complaint Unresolved
# Insufficient L1 Offer
# Prolonged Issue
# Unresolved Financial Impact
# Outside L1 Mandate
# Demand for Specific Redress
# Unable to Investigate
# Unsatisfactory L1 Investigation
# Unresolved Inquiry & Poor Experience
# Agent Error / Inadequate Explanation
# Denied Claim Appeal
# Request for Compensation
# Incorrect L1 Analysis
# L1 Capability Gap
# Unresolved L1 Issues
# Repeat Complaint
# Denied Request / Unmet Expectation
# Recurring Unresolved Issue
# Unresponsive Channel
# Perceived Inaction
# Failure to Reimburse Costs
# L1 Agent Inability/Authority
# Agent Advised Escalation
# Policy/Business Decision Dispute
# Request for System Enhancement
# Inflexible Authentication Process
# Empowerment/Policy Limit
# Failure of Internal Process
# Seeking Compensation
# Policy/Decision Dissatisfaction
# Policy Decision
# Customer Disagreement with Policy
# Dissatisfied with Frontline Response
# Resolution Ineffectiveness
# Agent Skill/Knowledge Gap
# Incorrect L1 Information
# Unaddressed Consequential Concern
# Request Outside L1 Authority
# Failure of Standard Process
# Dissatisfaction with Policy/Process
# Supervisor Unavailability
# Denied Request at Branch
# Poor Frontline Service
# Request Denied at L1
# Turnaround Time Not Met
# Unworkable Solution Offered
# Policy/Process Constraint
# Resolution Timeframe
# Inadequate Frontline Response
# Financial Impact Investigation
# L1 Resolution Incapability
# No Response to Prior Complaint
# Failed Previous Resolution
# Poor Customer Handling
# Unresolved/Escalated
# Lack of L1 Information
# Request Exceeded L1 Mandate
# Immediate Escalation
# Promised Action Not Taken
# Financial Impact Unresolved
# Explanation Not Provided
# L1 Triage/Escalation
# Unfulfilled L1 Resolution
# Initial Request Not Met
# Resolution Not Timely
# System Limitation
# Lack of L1 Knowledge
# Issue Requires Specialist
# Dissatisfaction with Frontline Response
# L1 Process/Policy
# Poor L1 Response
# Failed Promise / Follow-up
# Dissatisfied with Response
# Unmet Customer Need
# Dissatisfied with L1 Offer
# System Escalation Error
# Delayed/No Resolution
# Unresolved Compensation
# Awaiting Call Review
# Inability to Reach L1
# Resolution Timeframe Dissatisfaction
# Incorrect Diagnosis at L1
# Failure of Previous Channel
# Insufficient L1 Explanation
# No Resolution Provided
# Failure to Address Request
# Failure of L1 to Resolve
# Service Delay / Lack of Follow-up
# Sensitivity of Complaint
# Inadequate L1 Communication
# Previous Advice Contradicted
# L1 Empowerment / Policy
# L1 Resolution Not Offered
# Poor L1 Investigation
# Excessive Wait Times
# Unaddressed Core Complaint
# L1 Ineffective Resolution
# Resolution Not Meeting Expectation
# Incorrect Resolution
# Customer Refused L1 Resolution
# Compensation Denial
# Agent Inability to Investigate
# Proposed Solution Rejected
# Failure to Accommodate Vulnerable Customer
# Perceived Poor Service at Branch
# Incorrect Information at L1
# Inadequate Investigation/Answer
# Unresolved Initial Request
# L1 Declined Request
# Unaddressed Service Issue
# Client Request for Process Review
# Unacceptable Solution
# Security Concerns
# Internal Handoff Failure
# Dissatisfaction with L0 Service
# Prolonged Delay
# Perceived Agent Misconduct
# Resolution Did Not Address Complaint
# Incomplete L1 Investigation
# L1 Investigation Limitation
# Resolution Gap
# System/Process Limitation
# L1 Policy Recitation
# Demand for Senior Staff
# Lack of Authority
# Ignored Feedback
# Advisor Non-responsive
# Language of Service
# Unresolved at First Touchpoint
# Failed Resolution/Workaround
# Customer Rejected L1 Resolution
# Agent Empowerment/Authority
# Poor Service Interaction
# Lack of Clear Explanation
# Customer Misunderstanding
# Failure to Communicate Resolution
# Process Dead-End
# Non-response from initial contact
# Lacked Resolution Authority
# Lack of Contact
# Compensation Request Unmet
# Unfulfilled Callback Request
# Authority Limits
# Information Unavailable at L1
# No Response from Bank
# Non-Response
# Frontline Inability to Assist
# Unresolved by Third-Party
# Loss of Trust / Confidence
# Severity of Impact
# L1 Lacked Authority/Information
# Third-Party Unresponsive
# Request Not Met at L1
# L1 Lack of Authority
# Unsatisfactory Explanation at L1
# Dissatisfaction with Process Speed
# L1 Denial of Request
# L1 Unable to Provide Information
# Failure to Investigate at L1
# Request for Historical Recourse
# Conflict of Interest
# Failure to Contact at L1
# Rate Match Declined
# L1 Resolution Delay
# Failed Contact Attempt
# Dissatisfaction with L1 Explanation/Solution
# Allegation of Bank Liability
# Unresolved at Initial Touchpoint
# Resolution Not Trusted
# Agent Refusal to Transact
# Call Review Request
# Unsatisfied with Proposed Solution
# Lack of Empowerment/Scope
# Inaccessible Frontline
# L1 Refusal of Goodwill
# Misrouted Complaint
# Failure to Contact
# Dissatisfied with Proposed Solution
# Branch Inaction
# Unresolved Service Complaint
# Resolution Timeline Breach
# L1 Agent Empowerment
# Relationship Breakdown
# Process Delay & Poor Communication
# L1 Non-Engagement
# Failure to Investigate/Address
# Lack of Empathy/Resolution at Branch
# Investigation Complexity
# Complexity/Mandate
# Frontline Unable to Resolve
# L1 Lacked Capability
# Poor L1 Resolution
# Dissatisfaction with Policy/Outcome
# Multiple Service Failures
# Complaint Complexity & Financial Claim
# L1 Unable to Authorize Exception
# Dissatisfaction with Timelines
# L1 Triage/Process
# Dissatisfaction Not Addressed
# Unmet Compensation Request
# Unsuitable Resolution
# Dissatisfaction with Branch Outcome
# Perceived Lack of Resolution
# Dissatisfaction with Explanation/Resolution
# Failure to Resolve at Touchpoint
# Staff Attitude & Unresolved Issue
# L1 Resolution Declined
# Unresolved Root Cause
# Perceived Delay in Resolution
# Unmet Client Demand
# Staff Error/Misinformation
# Rejected L1 Finding
# Perceived Lack of Action
# L1 Failure to Contact
# Denied Refund Request
# No Response at Touchpoint
# Dissatisfaction with Advice
# Inter-departmental Runaround
# Dissatisfaction with Policy / Goodwill
# Failure of Frontline Resolution
# Poor Service Recovery
# L1 Unclear on Process
# Complex Decision Review
# Service Recovery Failure
# System Issue Unresolvable at L1
# Explanation Requested
# Dissatisfaction with Initial Action
# Departmental Runaround
# Inaccurate Information Provided
# Dissatisfaction with Investigation
# L1 Unable to Explain Policy
# L1 Agent Lacks Authority
# Unaddressed Request
# Lack of Resolution/Update
# Decision Explanation/Appeal Required
# Poor Service
# Unresolved Feedback
# L1 Resolution Did Not Meet Customer Expectation
# Process Change Request
# Agent Failure to Resolve
# Disagreement with Factual Finding
# Lack of Empowerment/Tools
# L1 Inability to Investigate
# Agent Authority/Knowledge
# Lack of L1 Empowerment/Support
# Legal Involvement
# Unsatisfactory Previous Response
# Procedural Deadlock
# Communication Barrier
# No Response to Inquiry
# Service Promise Not Met
# L1 Unwilling to Waive Fee
# Claim for Compensation
# Internal System Failure
# Previous Complaint Mishandled
# Agent Authority/Knowledge Gap
# Specialized Handling Required
# Poor In-Branch Handling
# L1 Empowerment/Process
# Jurisdictional Limitation
# L1 Failure to Explain
# Refusal to Provide Documentation
# Denial of Service
# Refund Denial
# L1 Unable to Meet Demand
# Failure of Prior Interaction
# Policy/Authority Limitation
# Resolution Complexity
# Direct to L2 (Regulator)
# Dissatisfaction with Resolution Time
# Resolution Impasse
# Dissatisfaction with Resolution / Redress
# Failure of Self-Serve & In-Person Channels
# Lack of Confidence in L1
# Frontline Unable to Assist
# Timeline Dissatisfaction
# Resolution Time
# Dissatisfied with Decision
# Lack of Resolution at Touchpoint
# Denied Reimbursement
# Lack of L1 Resolution Path
# Internal Process Failure
# Threat of Further Escalation
# Non-Response at Touchpoint
# Inadequate L1 Investigation/Explanation
# Inadequate L1 Investigation/Resolution
# Inadequate L2 Offer
# L1 Resolution Limitation
# Unsatisfactory L1 Decision
# L1 Explanation Not Accepted
# Incomplete Prior Resolution
# Failure to Resolve at Point of Contact
# Dissatisfaction with Claim Outcome
# Poor Staff Attitude
# Policy/Information Gap at L1
# L1 Referral Process
# Agent Not Empowered
# Failure to Resolve & Conflicting Advice
# Systemic Issue Feedback
# Specialized Team Required
# Dissatisfaction with Process/Timeline
# Failed Follow-up
# Agent Lacked Information/Authority
# Customer Request for Compensation
# Unanswered Question
# New Issue Post L1
# Initial Interaction Failure
# Employee Runaround
# Goodwill Request Denied
# Process Deadlock
# L1 Complaint Mishandling
# Delayed Response
# Disagreement with Resolution
# Dissatisfaction with Partner's Decision
# Cross-Departmental Issue
# Disagreed with Outcome
# Failure to Contact Customer
# Perceived Branch Inaction
# Misinformation from L1
# L1 Lacked Empowerment/Info
# Agent Incapable of Fulfilling Request
# Agent Authority Limit
# Decision Review Requested
# Branch Failure to Resolve
# Sales Practice Investigation Request
# L1 Triage/No Mandate
# L1 Authority Limitation
# Dissatisfied with Information
# Unsatisfactory Branch Advice
# L1 Resolution Constraint
# Lack of L1 Empowerment/Expertise
# Decision Outside L1 Authority
# Process/Authority Limitation
# Inconsistent Information Provided
# Policy/Procedure
# Frontline Unresponsive
# Unsatisfactory Resolution & Poor Service
# Unhelpful Advice
# Urgency of Request
# Unfavorable Fraud Decision
# Denied In-Call Escalation
# Complaint Handling Dissatisfaction
# Agent Inflexibility
# Poor L1 Explanation
# Communication Failure
# Lack of L1 Ownership
# Unresolved System Issue
# Request for Formal Review
# Monetary Dispute
# Process Delay / Auto-Escalation
# Third-Party Issue
# Threat of Legal Action
# Customer Disagreement with L1 Findings
# Failure to Escalate
# L1 Inactivity / Timeout
# Auto-Escalation (Inactivity)
# Continued Service Failure
# Staff Unresponsiveness
# L1 Agent Ineffectiveness
# Incorrect L1 Advice
# Denial of Fraud Claim
# Requires Specialist Review
# Failure to Resolve in Time
# Unresolved Initial Complaint
# Need for Investigation
# Unclear Denial Reason
# L1 Investigation & Handoff
# Failed L1 Investigation
# Unclear L1 Process
# Dissatisfaction with Outcome & Process
# Resolution Rejection
# Lack of Follow-through
# Fraud Allegation
# Unresponsive Service
# Lack of Response / Follow-up
# Query Beyond L1 Mandate
# Media Involvement
# Dissatisfied with L1 Process
# Resolution Speed
# Appeal of Decision
# Dismissal of Complaint
# Failure of Promised Action
# Knowledge Gap
# Denial of Escalation
# Severity of Misconduct
# Failure to Respond
# Resolution Denial
# Inadequate Initial Response
# No Resolution Attempted
# Direct Transfer
# Negative Credit Bureau Impact
# Missed Callback
# Ineffective L1 Handling
# Poor Hand-off / Deflection
# Investigation Request
# Dissatisfaction with Initial Service
# L1 Empowerment/Process Gap
# Failure to Resolve at Lower Levels
# Unacceptable Wait Time
# Failure to Resolve Recurring Issue
# Disagreement with Bank Policy
# L1 Not Empowered
# Inaction on Previous Request
# Inadequate L1 Handling
# Systemic Issue Identification
# Proactive Escalation by Bank
# Poor Staff Experience
# Branch's Refusal to Resolve
# Expectation Mismanagement
# L1 Unable to Overturn Decision
# SLA Breach by Internal Team
# Case Complexity
# Immediate Resolution Demanded
# Unresolved Issues
# Query Requires Specialist Knowledge
# Frontline Unable to Explain
# Dissatisfaction with Policy/Limitation
# Dissatisfaction with Interaction
# L1 Service Dissatisfaction
# Unfulfilled Request
# Disagreed with Explanation
# Lack of Empowerment/Process
# Customer Loss of Trust
# Unresponsive Internal Department
# Unaddressed Root Cause
# Lack of Transparency
# Customer Disagreed with Explanation
# Policy Exception Request
# Branch Unable to Assist
# Inadequate In-Branch Resolution
# Inability to Resolve at Frontline
# Dissatisfaction with Initial Handling
# Lack of L1 Empowerment/Information
# Lack of Follow-up / Response
# Customer Demand
# Agent Incapable of Resolution
# L1 Lacked Authority/Scope
# L1 Agent Did Not Waive Fee
# Failed Resolution/Promise
# Unsatisfactory Local Resolution
# Multiple Unresolved Issues
# Policy/Process Deadlock
# Customer Dissatisfaction with Outcome & Service
# Incorrect L1 Handling
# Denied Financial Reimbursement
# Request Required Specialist Review
# Disagree with Outcome
# L1 Refusal to Waive Fees
# Failure of Initial Channel
# Complex Issue
# Dissatisfaction with Policy/Procedure
# Staff Knowledge Gap
# Perceived Lack of Ownership
# Resolution Not Confirmed
# Unsatisfactory Response/Resolution
# Dissatisfaction with Employee
# Client Dissatisfaction with Resolution
# Unsatisfactory Initial Service
# Failed Investigation
# Disagrees with Decision
# Disagreement with Initial Decision
# Privacy Concern
# L1 Denial of Refund
# L1 Decision Not Accepted
# Administrative Error
# L1 Misdiagnosis
# Failed Resolution Attempts
# Agent Conduct Investigation
# Inability to Provide Policy Proof
# Unfulfilled Promise (Perceived)
# Unresolved Credit Bureau Impact
# L1 Agent Empowerment/Policy
# Unsatisfactory L1 Experience
# Failed Escalation Request
# Direct Escalation
# Threatening/Coercive Communication
# L1 Unable to Assist
# L1 Lacked Resolution Path
# L1 Inability to Diagnose
# Prolonged/Unresolved Issue
# Dissatisfaction with Compensation
# Delayed Resolution at L1
# Inability to Provide Information
# L1 Investigation Inconclusive
# Dissatisfaction with L1 Explanation/Outcome
# Advisor Lacked Knowledge/Skill
# No ETA for Fix
# Process-driven Escalation
# L1 Lacked Resolution Knowledge
# Previous Attempts Ignored
# Unaddressed Service Grievance
# Process Unclear to Client
# Disagreement with Evidence
# Unresolved Negative Impact
# Erroneous Escalation
# L1 Authority/Process Limits
# Dissatisfaction with L1
# Unresolved Recurring Issue
# Requires Investigation
# Inability to Provide Proof
# Felt Unheard
# Branch Inability to Resolve
# Unclear Explanation
# Lack of Investigation at L1
# Compensation Claim
# Poor Service & No Solution
# Dissatisfaction with L1 Response/Handling
# Internal Escalation for Feedback
# Unresolved Core Issues
# L1 Mandate Limit
# Failure to Provide Information
# Unresponsive Advisor/Branch
# L1 Information Gap
# Unresolved Issue & Broken Promises
# Non-response from Staff
# Unable to Contact Customer
# Customer Dissatisfaction with Outcome
# Expectation Mismatch
# Poor Service at L1
# Policy Constraints
# Process Error
# Unresolved Prior Issue
# Ineffective L1 Handoff
# Channel Conflict
# Perceived Delay / No Update
# Unsatisfactory Resolution/Timeline
# Disagreement with L1 Decision
# Previous Resolution Ineffective
# Initial Response Failure
# Client Unacceptance of Policy
# Frontline Unable to Investigate
# Regulatory Compliance Concern
# Desire for Senior Review
# Agent Lacked Authority/Knowledge
# Loss of Trust / Accusation
# Dissatisfaction with Resolution Scope
# Unacceptable Branch Response
# Customer Disagreed with L1 Finding
# Resolution Failure at Frontline
# Unsatisfactory Initial Decision
# L1 Lacked Resolution Authority
# Denial of Goodwill Request
# Lack of Permanent Resolution
# Dissatisfaction with Branch
# Policy Decision Required
# Customer Refusal of Solution
# Financial Hardship
# Dissatisfaction with Update
# Policy/Process Inquiry
# Impact of Previous Error
# Failure of Business Unit to Resolve
# L1 Resolution Incapacity
# Dissatisfied with L1 Explanation/Outcome
# Request Denied
# Failure to Address Original Complaint
# Allegation of Discrimination
# No L1 Resolution/Authority
# Failed Authentication
# Dissatisfaction with L1 Resolution/Advice
# Unacceptable Staff Conduct
# Client Request & Unresolved Issue
# L1 Resolution Not Possible
# L1 Unable to Explain Root Cause
# Reputational Risk
# Client Dissatisfaction with L1 Outcome
# Denied Compensation
# Dissatisfaction with Claim Denial
# L1 Dismissal of Fraud Claim
# Complex Investigation Required
# Dissatisfied with Solution
# L1 Failed to Deliver on Promise
# L1 Agent Authority/Skill
# Incorrect Advice/Information
# Prior Contact Unresolved
# Promise Not Met
# L1 Agent Incapable
# Client Insistence on Formal Escalation
# Customer Disagrees with Resolution
# Unresolved Prior Contacts
# Poor Handoff
# Dissatisfied with Perceived Outcome
# Inability to Provide Interim Relief
# Unclear L1 Resolution
# Information Gap
# Unfair Process
# Request Declined
# L1 Triage Failure
# Initial Process Failure
# Channel Bouncing
# Customer Disagrees with Findings
# Agent Capability/Authority
# Privacy Breach
# Client Dissatisfied with L1 Outcome
# Customer Dissatisfaction with L1
# First Contact Failure
# Unresolved Issue & Failed Callback
# Unsatisfactory Staff Interaction
# Compensation Limit
# Financial Compensation Request
# Dissatisfied with L1 Decision
# Impact of Agent Error
# Severity of Initial Incident
# Broken Promise
# Failed Callback
# Dissatisfaction with L1 Action
# Unsatisfactory Fraud Decision
# Perceived Recurring Issue
# Dissatisfaction with Situation
# Agent/Department Runaround
# Request Exceeds L1 Mandate
# Authentication Failure
# Long Wait Times
# Proposed Resolution Unacceptable
# Inadequate L1 Support Tools
# Request for Internal Review
# Agent-Initiated Escalation
# Poor In-Person Service
# Incorrect Routing at L1
# Inadequate Resolution Timeframe
# Misunderstood Complaint
# Proactive escalation
# Perceived Lack of Assistance
# System/Policy Limitation
# Customer Conduct Dispute
# Process Disagreement
# Poor L1 Handling / Deflection
# Investigation Timeline
# Refusal to Make Exception
# Inability to Meet Demand
# Unsuitable Resolution Offered
# Denied Resolution
# L1 Triage/No Investigation
# Branch Resolution Rejected
# L1 Agent Error
# Inadequate Resolution at First Contact
# Refund Amount Dispute
# Customer Request for Senior Review
# Inadequate L1 Resolution Offer
# Perceived Complexity
# Unsatisfactory L1 Solution
# Complaint Type Requires Investigation
# Inadequate L1 Resolution/Advice
# Untimely Resolution
# L1 Inability to Explain
# Dissatisfaction with L0 Handling
# Lack of Updates
# L1 Unable to Provide Financial Resolution
# L1 Referral for Resolution
# L1 Disagreement with Client
# Investigation Gap
# Information Not Available to Agent
# Decision Not Accepted
# Disagreement with L1 Findings
# Manager Request
# Inconsistent Advice
# Disagree with Decision
# Repeated Service Failure
# Dissatisfaction with L2 Resolution
# Rejected Resolution
# Investigation Delay / Ineffective
# Failure to Resolve & Poor Service
# Unsatisfactory Explanation / Resolution
# Service Delay
# Poor Agent Handling
# Agent Refused Escalation
# Unsatisfactory Recall Process
# Refusal of Offshore Service
# Unsatisfactory Previous Interaction
# L1 Lacked Information/Authority
# Policy/System Limitation
# Impact of Error
# Channel Failure
# Dissatisfaction with Service Experience
# L1 Agent Lacked Authority/Tools
# Inadequate Prior Resolution
# Unsatisfactory Resolution/Explanation
# Unsatisfactory Advice
# L1 Inaccessibility
# Dissatisfaction with L1/Branch Outcome
# Unresolved Payment Allocation Issue
# Policy Issue
# Threat of Legal/Media Action
# Policy/Procedural Limitation
# Customer Felt Unheard
# L1 Lacks Authority/Tools
# Process Deadlock/Delay
# Inability to Validate Customer Claim
# Failure to Honor Agreement
# Alleged Misinformation by Staff
# Lack of L1 Response
# Resolution Beyond L1 Authority
# Dissatisfaction with Handling
# Procedural Hand-off
# L1 Misinterpretation
# Policy/Process Limitation at L1
# Inability to Authenticate
# Poor Frontline Experience
# Inability to Meet Request
# Failure to Attempt Resolution
# Perceived Discrimination
# Initial Resolution Failure
# Service Breakdown
# Resolution Amount Dissatisfaction
# Query Complexity
# Frontline Resolution Limitation
# Unsatisfactory Resolution at Prior Stage
# Disagreement with Valid Charge
# Compensation Request Unresolved
# Failure to Resolve/Own
# Agent Empowerment/System Limitation
# Nature of Complaint (Privacy)
# Alleged Misinformation
# Customer Bounce
# Non-response from internal department
# Limited Authority
# Failure to Reach Agent
# L1 Inability to Fulfill
# Resolution Not Feasible
# Policy Application
# Feedback Escalation
# Complexity/Sensitivity of Issue
# Jurisdictional Hand-off
# Disputed Liability
# Failure of Standard Channels
# Lack of Frontline Response
# Process Mandated Escalation
# Customer Expectation Not Met
# Perceived Inaction at L1
# Disagreement with Insurer's Decision
# Claim Denied at L1
# Dissatisfaction with Resolution Timeline
# Inability to Investigate at L1
# Policy Upheld / Exception Denied
# Agent Communication Failure
# Refusal to Assist at Branch
# Recurring Issue Unresolved
# Lack of Reassurance
# Poor Service/Handling
# L1 Lacked Access/Authority
# Perceived Policy Restriction
# Knowledge Gap at L1
# Dissatisfaction with Frontline Explanation
# Agent Lacks Authority
# Poor L1 Resolution Handling
# Internal Ownership Dispute
# Agent Inability to Assist
# Decision Requires Higher Authority
# L1 Process
# Unresponsive Internal Team
# Dissatisfaction with Initial Interaction
# Misinformation from Agent
# Resolution Did Not Address Root Cause
# Dissatisfaction with L1/Partner Resolution
# Unable to Fulfill Request
# L1 Unempowered
# Unclear Internal Information
# Compensation Demand Exceeds Authority
# Inadequate L1 Resolution (Experience)
# Unsatisfactory Internal Response
# Dismissal of Customer's Claim
# Request for Senior Review
# Inability to Investigate/Resolve
# Unable to Provide Proof
# Dissatisfied with Explanation/Solution
# Misinformation at L1
# Customer Request for Supervisor
# L1 Unable to Diagnose
# Process Bypass Attempt
# L1 Inability to Fulfill Request
# Lack of Clarity from L1
# Lack of Clear Path/Solution
# Poor Agent Interaction
# Investigation Outcome Dissatisfaction
# Inability to Meet Customer Need
# Dispute Outcome Dissatisfaction
# Dissatisfaction with Agent & Compensation Request
# Inability to Fulfill Request at L1
# Initial Decision Unacceptable
# Process Gap
# Resolution Insufficient
# Dissatisfaction with Previous Interaction
# Unmet Expectations from Prior Contact
# Contact Channel Failure
# Refusal to Accept Policy
# Unaddressed Customer Request
# Advisor Unresponsiveness
# Lack of L1 Resolution Attempt
# Poor Investigation
# L1 Advice Ineffective
# Unable to Resolve at L1
# Failure of Initial Resolution
# Demand for Compensation
# Agent Empowerment/Authority Limit
# Disagreed with L1 Explanation
# Dissatisfaction with Explanation/Wording
# Agent Error/Poor Explanation
# Unaddressed Process Concern
# L1 Incapable/Unempowered
# Unresponsive Employee
# Lack of Scope
# Specialized Request
# L1 Unable to Inform
# Unresolved at First Touch
# Dissatisfied with L1 Solution
# Dissatisfaction with previous outcome
# Inadequate Resolution/Empowerment
# Non-response from branch
# Process Driven
# Perceived Broken Promise
# L1 Mandate/Process
# Authentication/Privacy Requirements
# Manager Failed to De-escalate
# Unsatisfied with L1 Resolution
# Accidental Escalation
# Misinformation
# Inadequate Initial Resolution
# Agent Incapable/Unempowered
# Solution Not Accepted
# L1 Empowerment/Policy Constraint
# Complaint Severity/Policy
# Incomplete L1 Triage
# L1 Refused Goodwill
# Inadequate Frontline Resolution
# Failure to Take Ownership
# L1 Resolution Authority
# Dissatisfied with Policy/Explanation
# Investigation Failure
# L1 Empowerment
# High Amount
# Complaint About Staff
# Lack of Authority at L1
# Impact on Credit
# Process/Tool Limitation
# L1 Intake Only
# Service Level Agreement Breach
# Inadequate Explanation at Touchpoint
# Prior Unresolved Contacts
# L1 Lacked Information/Tools
# Customer Dissatisfaction with Solution
# Unsatisfactory Solution at L1
# Dissatisfaction with Branch Management Response
# Denied Request at L1
# Appeal of Fraud Decision
# Process Failure at First Contact
# Reversal of Provisional Credit
# Denial of Request at L1
# L1 Triage / No Resolution Attempted
# L1 Lacked Access/Tools
# Failure of Primary Channel
# L1 Process Adherence
# Unacceptable L1 Resolution
# Unaddressed Concerns
# Unsatisfactory L0 Decision
# Unsatisfactory Response/Action
# Failure of L1 Resolution
# Lack of L1 Authority/Expertise
# Failure to Resolve & Staff Conduct
# Lack of L1 Authority/Capability
# Agent Error / Knowledge Gap
# Interest Waiver Demand
# Lack of L1 Authority/Visibility
# Refusal of Request
# Internal Non-cooperation
# Poor Initial Handling
# Frontline Inability to Explain
# Complaint Not Addressed
# Incorrect Expectation Set by Staff
# Process Delays
# Service Failure & Security Concern
# L1 Inaction/Delay
# Unresolved Issue/Broken Promise
# Feedback/Suggestion
# Lack of L1 Support
# Lack of L1 Authority/Knowledge
# Unsatisfactory Branch Management Response
# Advisor Non-Response
# Resolution Limitation
# Lack of L1 Authority/Info
# Out of Scope for L1
# Dissatisfaction with L1/Branch Response
# Lack of Action / Follow-up
# Failure to Escalate / Log Complaint
# Systemic Fix Request
# Exceeded Authority
# Service Failure at First Contact
# L1 Lacked Proof/Authority
# Unclear Policy/Procedure
# Poor Explanation / Empathy
# Failure to Resolve Prior Complaint
# Unresolved Technical Issue
# Process Timeline Dissatisfaction
# L1 Error
# L1 Failure to Address
# Unaddressed Customer Concern
# Unsatisfactory Workaround
# Branch Failed to Resolve
# Incorrect L1 Finding
# Client Disagrees with Outcome
# Client Request to Escalate
# Lack of Clarity on Outcome
# Resolution Not Implemented/Effective
# Urgency/Impact
# L1 Authority/Tooling Limit
# Customer Dissatisfaction with L1 Interaction
# Guidance Required
# Empowerment/Authority Issue
# L1 Incapable/Process
# Urgency/Client Impact
# Agent Lacked Access
# Unresolved at L1 / Delay
# Customer Dissatisfaction with L1 Outcome
# Refund Amount
# L1 Resolution Limit
# No L1 Response
# Complaint Complexity & Impact
# Advice Not Accepted
# Resolution Did Not Meet Expectations
# Ineffective Solution
# Unmet Fee Waiver Request
# Investigation Failure at L1
# Service & Resolution Dissatisfaction
# System Issue Investigation
# Severity of Bank's Action
# Unempowered L1 Agent
# Inadequate L1 Response/Explanation
# Unsatisfactory Resolution Attempt
# L1 Inactivity
# L1 Resolution Timeout
# Customer Refused Resolution
# Disagreed with L1 Decision
# Inadequate L1 Triage
# Poor Communication of Resolution
# Lack of Empowerment/Information
# Customer refused solution
# Process Deadlock/Gap
# Failure to Communicate Outcome
# L1 Empowerment/Policy Limitation
# Unmet Resolution Timeframe
# Resolution Offered Rejected
# Unsatisfactory Prior Handling
# Policy/Process Disagreement
# Unacceptable Offer
# Customer Request for Management Review
# Unsatisfactory Response at Branch
# Service/Communication Failure
# Incorrect Reason for Denial
# Process Failure / Delay
# Unsatisfactory Resolution/Response
# Poor Solution Offered
# Inadequate Goodwill Offer
# Unfair Bank Decision
# Unresponsive Department
# Customer Dissatisfaction with Policy/Feature
# Prior Resolution Ineffective
# Service Quality & Dissatisfaction with L1 Resolution
# Poor L1/Branch Experience
# Unmet Resolution Expectation
# Nature of Complaint (Legal)
# Immediate Transfer
# Resolution Not Actioned/Communicated
# L1 Resolution Denied
# Unresolved Issue & Process Failure
# Complaint Mishandling
# Complaint Complexity / Compensation Request
# Inadequate Resolution/Compensation
# L1 Incapable
# Improper L1 Routing
# Denial of Ownership
# Process Inefficiency
# Agent Lacked Access/Authority
# Inability to Address Core Issue
# Agent De-escalation Failure
# Unfulfilled L1 Promise
# Inability to Validate Claim
# Perceived Resolution Delay
# Dissatisfaction with L1 Resolution/Service
# L1 Process/Scope
# Unsatisfied with L1 Explanation
# L1 Policy Limitation
# Poor In-Branch Experience
# Customer Disagreed with Policy
# System/Process Issue
# Customer Dissatisfaction with L1 Channel
# L1 Unable to Provide Reason
# Inadequate L1 Investigation & Resolution
# Service Denial
# Agent Authority/Empowerment
# Lack of Authority/Information
# Lack of Empowerment / Authority
# Incorrect Department/Routing
# Unclear L1 Explanation
# Unresolved Branch Issue
# Poor Communication / Unresponsiveness
# Disagrees with Claim Decision
# L1 Out of Scope
# Compensation Declined
# L1 Inability to Assist
# Initial Request Ignored
# Long Wait Time
# L1 Incorrect Decision
# Customer Rejected L1 Position
# Dissatisfaction with Offered Solution
# Dissatisfaction with SLA
# Internal Delay
# Misinformation from Staff
# Dissatisfaction with L1/Dispute Outcome
# Failure to Resolve / No Follow-up
# Dissatisfaction with Product
# Dismissal of Concerns
# Client Dissatisfaction with Explanation
# Unclear Ownership
# Agent Misinformation
# Dissatisfaction with L1 Proposed Solution
# Failure to Resolve at Prior Touchpoint
# Frontline Referral
# Recurrence of Issue
# Customer Bounce-Around
# Unprofessional Agent
# Dissatisfaction with Timeframe
# Non-Response to Follow-up
# Unresolved Refund Request
# Incorrect Resolution at L1
# Dissatisfied with Explanation/Outcome
# L1 Authority/Policy Limitation
# L1 Created/Worsened Issue
# Unresolved Service Issues
# Complex Inquiry
# Poor Explanation
# Disagreement with Proposed Solution
# Initial Contact Failure
# Delayed Internal Follow-up
# Delayed Resolution & Lack of Follow-up
# Unresponsive to Inquiry
# Process Limitations
# Advice Dissatisfaction
# Failure of prior resolution attempt
# Internal Inaction
# Issue Recurrence
# Dissatisfaction with L1/Initial Decision
# Failure of Resolution Path
# L1 Diagnostic Failure
# Refusal to Escalate/Disconnect
# L1 Data Mismatch
# Compensation Demand Not Met
# Threat of External Action
# Customer Rejects Explanation
# L1 Agent Uninformed
# Referral without Resolution
# Dissatisfaction with L1 Decision/Explanation
# Channel Authority Limit
# Resolution Timeframe & Compensation
# Dissatisfaction with L1 Explanation/Process
# L1 Lacked Documentation
# Lack of L1 Authority/Access
# Resolution Timeline Unacceptable
# Unsuitable L1 Resolution
# L1 Mandate/Authority Limit
# L1 Investigation Gap
# Unresolved Financial Claim
# Dissatisfaction with Delay
# User Experience Feedback
# Scope Limitation
# Lack of Information / Answer
# Advised to Escalate
# Runaround/Incorrect Redirection
# Request Outside L1 Mandate
# L1 Decision to Escalate
# Referral to Specialist Team
# Customer Dissatisfaction with L1 Explanation
# Inadequate L1 Empowerment
# L1 Ownership Failure
# Customer wanted to provide feedback
# Agent Capability/Knowledge Gap
# Dissatisfaction with Agent Service
# Compensation Refused
# Dissatisfaction with Financial Outcome
# L1 Resolution Offer
# Policy Feedback
# Severity of L1 Experience
# Prior Unresolved Complaint
# Advisor Misinformation/Dismissal
# Perceived Lack of Solution
# Unresolved Compensation Claim
# Unresolved Misinformation Concerns
# Failed Complaint Follow-up
# Perceived Staff Inaction
# Technical Investigation Required
# Client Aggression & Termination
# Dissatisfaction with L1 Offer
# L1 Service Gap
# Threat of Litigation
# Re-complaint on Final Decision
# Lack of Investigation Update
# Complexity of Complaint
# Lack of Resolution Update
# Unsatisfactory Offer
# Unmet Demand for Compensation
# Unaddressed Core Concern
# Agent Misunderstanding
# Resolution Not Effective
# Claim Partially Denied
# L1 Unable to Compensate
# Dissatisfaction with L1 Information
# L1 Lacks Authority/Info
# Complaint about Staff Conduct
# Disputed Investigation Finding
# Inadequate Branch Explanation
# Request for Financial Remedy
# Process/Policy Gap
# Inability of L1 to Resolve
# Failure to Address
# Failure to Troubleshoot
# L1 Failure to Address Concern
# Multi-channel Service Failure
# Resolution Inadequacy
# Customer Unhappy with Explanation
# Lack of Clear Guidance
# Inadequate L1 Resolution/Authority
# Prior Resolution Not Communicated
# Exception Request Denied
# Unrelated L1 Issue
# Dissatisfaction with Service & Fee Dispute
# Monetary Resolution Request
# Unsatisfied with Branch Decision
# L1 Process Hand-off
# Denial of Reimbursement
# L1 Agent Lack of Authority
# L1 Process/Mandate
# Unable to Validate Promise
# Lack of Resolution/Timeline
# Dispute of Liability
# Client Dissatisfaction with Initial Service
# Service & Process Failure
# Dismissal of Concern
# L1 Resolution Did Not Address Core Issue
# Investigation Limit Reached
# Initial Decision Rejection
# Inconsistent Service
# L1 Investigation Delay
# L1 Agent Not Empowered
# Reimbursement Request
# Repeat Issue & Client Request
# Channel Accessibility Failure
# Unresolved Issue (Statements)
# Client Request for Investigation
# L1 Triage/Hand-off
# Remedy/Compensation Request
# Denied Compensation Request
# L1 Inability to Fulfill Resolution
# Monetary Demand
# Rejection of Explanation
# Unsatisfactory L0 Experience
# Failed Explanation
# Credit Bureau Dispute
# L1 Denial of Error
# Unsatisfactory L1 Investigation Outcome
# Unresolved Service Failure
# Unaddressed Concern
# No Response to Complaint
# Repeat Service Failure
# Allegation of Employee Misconduct
# Service Failure Not Resolved
# Lack of L1 Tools/Authority
# Failure to Resolve / Ownership
# Resolution/Compensation
# Unresolved Staff Conduct
# Inadequate L1 Complaint Handling
# Agent Discretion/Authority Limit
# Agent Runaround
# Policy/Process Dispute
# Non-Monetary Resolution Request
# Lack of Information/Explanation
# L1 Agent Minimized Complaint
# Insufficient Reassurance
# Response Inadequate
# Lack of Confidence in Resolution
# Poor Staff Interaction
# Procedural Error
# L1 Goodwill Declined
# Failure to Reach Support
# Lack of Update on Dispute
# L1 Refund Authority Limit
# Unresolved Security Concern
# Unsatisfactory Resolution Options
# Non-receipt of Document
# Unsatisfactory Partner Resolution
# Disagreement with Claim Decision
# Severity of Claim
# Frontline Lacked Authority
# Failed Initial Process
# Inadequate Information Provided
# Unclear Prior Interaction
# Incomplete Resolution at L1
# Not Satisfied with Explanation
# L1 Lacked Tools/Authority
# Dissatisfaction with Fraud Claim Outcome
# Incorrect L1 Investigation
# Failure to Address Concern
# Lack of Response/Follow-up
# Request for Written Confirmation
# Ethical Concerns with Resolution
# Jurisdictional/Authority Limit
# Staff Attitude
# Investigation Limitations
# Perceived Discrimination & Unresolved Issue
# Non-response / Inaction
# Agent Error/Poor Advice
# Inability to Substantiate Fee
# Inadequate L1 Authority/Process
# Failure to File Complaint
# Request for Documentation
# Inability to Get Answer
# Unmet Demand
# Inquiry Required Specialist
# Dissatisfaction with Resolution Amount
# Liability Dispute
# Inadequate L1 Explanation/Service
# Inadequate Branch Support
# Inadequate Solution Offered
# Unclear L1 Communication
# Dropped Call
# Unclear Initial Response
# Customer Refused Authentication
# Request for Escalation
# Lack of L1 Outcome
# L1 Support Failure
# Dissatisfaction with Resolution & Delays
# Inadequate Initial Support
# Unsatisfactory L1 Proposal
# Limited Branch Authority
# Delayed Internal Process
# L1 Empowerment/Tools
# Customer Service Runaround
# L1 Triage/Referral
# Lack of L1 Update
# No Response from Department
# L1 Triage/Routing
# Poor Customer Service Experience
# Solution Dissatisfaction
# L1 Agent Conduct
